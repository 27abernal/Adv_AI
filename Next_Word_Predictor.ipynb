# %% [markdown]
# <a href="https://colab.research.google.com/github/27abernal/Adv_AI/blob/main/Next_Word_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
import torch

# Load model
print("Loading AI model...")
model_name = "distilgpt2"
tokenizer = AutoTokenizer.from_pretrained("distilgpt2")
model = AutoModelForCausalLM.from_pretrained("distilgpt2")
# Out:
# Loading AI model...

# %%
# Simple example
text = "The weather today is "
print(f"\nStarting text: '{text}'")
print("\nGenerating word by word...\n")

top_k = 20
temperature = 1.2

# Generate 5 words, one at a time
current_text = text
for step in range(30):
    print(f"--- Step {step + 1} ---")
    print(f"Current: '{current_text}'")

    # Encode current text
    input_ids = tokenizer.encode(current_text, return_tensors="pt")

    # Get predictions
    with torch.no_grad():
        outputs = model(input_ids)
        predictions = outputs.logits

    # Get the predictions for the NEXT token
    next_token_logits = predictions[0, -1, :]
    # Divide the raw scores by temperature
    # Lower temp = more focused; Higher temp = more random
    next_token_logits = next_token_logits / temperature
    next_token_probs = torch.softmax(next_token_logits, dim=0)

    # Get top predictions
    top_probs, top_indices = torch.topk(next_token_probs, top_k)

    print(f"Top {top_k} next word predictions (showing first 5):")
    for i, (prob, idx) in enumerate(zip(top_probs[:5], top_indices[:5])):
        word = tokenizer.decode([idx])
        print(f"  {i+1}. '{word}' ({prob.item()*100:.1f}% confident)")

    # --- CHANGE: Sampling logic replaces the 'top_indices[0]' line ---
    # This picks one index from top_indices based on the top_probs weights
    sample_idx = torch.multinomial(top_probs, num_samples=1)
    next_token_id = top_indices[sample_idx].item()
    # Use the most likely word
    # next_token_id = top_indices[0]
    next_word = tokenizer.decode([next_token_id])
    current_text += next_word

    print(f"✓ Chosen: '{next_word}'")
    print(f"New text: '{current_text}'\n")

print(f"\nFinal generated text: '{current_text}'")
# Out:
# Starting text: 'The weather today is '
#
# Generating word by word...
#
# --- Step 1 ---
# Current: 'The weather today is '
# Top 20 next word predictions (showing first 5):
#   1. 'iced' (29.4% confident)
#   2. ' ' (13.9% confident)
#   3. '!!!' (2.6% confident)
#   4. '�' (2.2% confident)
#   5. '????' (2.0% confident)
# ✓ Chosen: 'iced'
# New text: 'The weather today is iced'
#
# --- Step 2 ---
# Current: 'The weather today is iced'
# Top 20 next word predictions (showing first 5):
#   1. ' up' (8.0% confident)
#   2. ' with' (7.0% confident)
#   3. ' and' (5.5% confident)
#   4. '.' (5.3% confident)
#   5. ',' (5.2% confident)
# ✓ Chosen: ' up'
# New text: 'The weather today is iced up'
#
# --- Step 3 ---
# Current: 'The weather today is iced up'
# Top 20 next word predictions (showing first 5):
#   1. ',' (10.1% confident)
#   2. ' and' (9.7% confident)
#   3. '.' (7.1% confident)
#   4. ' by' (5.1% confident)
#   5. ' to' (3.8% confident)
# ✓ Chosen: ' and'
# New text: 'The weather today is iced up and'
#
# --- Step 4 ---
# Current: 'The weather today is iced up and'
# Top 20 next word predictions (showing first 5):
#   1. ' the' (3.8% confident)
#   2. ' ready' (3.0% confident)
#   3. ' it' (2.8% confident)
#   4. ' I' (2.7% confident)
#   5. ' we' (2.4% confident)
# ✓ Chosen: ' a'
# New text: 'The weather today is iced up and a'
#
# --- Step 5 ---
# Current: 'The weather today is iced up and a'
# Top 20 next word predictions (showing first 5):
#   1. ' bit' (8.6% confident)
#   2. ' little' (7.0% confident)
#   3. ' lot' (5.6% confident)
#   4. ' good' (2.3% confident)
#   5. ' few' (2.1% confident)
# ✓ Chosen: ' couple'
# New text: 'The weather today is iced up and a couple'
#
# --- Step 6 ---
# Current: 'The weather today is iced up and a couple'
# Top 20 next word predictions (showing first 5):
#   1. ' of' (42.7% confident)
#   2. ' more' (3.0% confident)
#   3. ' days' (2.6% confident)
#   4. ' things' (1.5% confident)
#   5. ' hours' (1.5% confident)
# ✓ Chosen: ' of'
# New text: 'The weather today is iced up and a couple of'
#
# --- Step 7 ---
# Current: 'The weather today is iced up and a couple of'
# Top 20 next word predictions (showing first 5):
#   1. ' days' (5.4% confident)
#   2. ' people' (3.1% confident)
#   3. ' hours' (2.8% confident)
#   4. ' things' (2.8% confident)
#   5. ' weeks' (1.6% confident)
# ✓ Chosen: ' other'
# New text: 'The weather today is iced up and a couple of other'
#
# --- Step 8 ---
# Current: 'The weather today is iced up and a couple of other'
# Top 20 next word predictions (showing first 5):
#   1. ' things' (11.3% confident)
#   2. ' people' (2.0% confident)
#   3. ' cool' (1.6% confident)
#   4. ' changes' (0.9% confident)
#   5. ' factors' (0.9% confident)
# ✓ Chosen: ' factors'
# New text: 'The weather today is iced up and a couple of other factors'
#
# --- Step 9 ---
# Current: 'The weather today is iced up and a couple of other factors'
# Top 20 next word predictions (showing first 5):
#   1. ' are' (13.3% confident)
#   2. ' will' (5.6% confident)
#   3. ' have' (5.2% confident)
#   4. ' that' (3.6% confident)
#   5. ' can' (2.7% confident)
# ✓ Chosen: ' could'
# New text: 'The weather today is iced up and a couple of other factors could'
#
# --- Step 10 ---
# Current: 'The weather today is iced up and a couple of other factors could'
# Top 20 next word predictions (showing first 5):
#   1. ' make' (6.7% confident)
#   2. ' affect' (6.7% confident)
#   3. ' be' (6.2% confident)
#   4. ' help' (5.5% confident)
#   5. ' change' (5.4% confident)
# ✓ Chosen: ' help'
# New text: 'The weather today is iced up and a couple of other factors could help'
#
# --- Step 11 ---
# Current: 'The weather today is iced up and a couple of other factors could help'
# Top 20 next word predictions (showing first 5):
#   1. ' to' (7.6% confident)
#   2. '.' (6.7% confident)
#   3. ' the' (4.8% confident)
#   4. ' you' (3.3% confident)
#   5. ' us' (2.8% confident)
# ✓ Chosen: ' us'
# New text: 'The weather today is iced up and a couple of other factors could help us'
#
# --- Step 12 ---
# Current: 'The weather today is iced up and a couple of other factors could help us'
# Top 20 next word predictions (showing first 5):
#   1. ' to' (9.1% confident)
#   2. ' get' (7.8% confident)
#   3. ' make' (2.9% confident)
#   4. ' keep' (2.2% confident)
#   5. ' in' (1.8% confident)
# ✓ Chosen: ' find'
# New text: 'The weather today is iced up and a couple of other factors could help us find'
#
# --- Step 13 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find'
# Top 20 next word predictions (showing first 5):
#   1. ' the' (12.1% confident)
#   2. ' a' (11.6% confident)
#   3. ' out' (8.0% confident)
#   4. ' some' (6.5% confident)
#   5. ' more' (2.3% confident)
# ✓ Chosen: ' out'
# New text: 'The weather today is iced up and a couple of other factors could help us find out'
#
# --- Step 14 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out'
# Top 20 next word predictions (showing first 5):
#   1. ' what' (14.0% confident)
#   2. ' more' (10.0% confident)
#   3. '.' (9.2% confident)
#   4. ' how' (5.7% confident)
#   5. ' if' (4.9% confident)
# ✓ Chosen: ' how'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how'
#
# --- Step 15 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how'
# Top 20 next word predictions (showing first 5):
#   1. ' to' (21.0% confident)
#   2. ' much' (7.4% confident)
#   3. ' the' (4.9% confident)
#   4. ' we' (4.4% confident)
#   5. ' this' (2.8% confident)
# ✓ Chosen: ' to'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to'
#
# --- Step 16 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to'
# Top 20 next word predictions (showing first 5):
#   1. ' get' (6.7% confident)
#   2. ' make' (6.6% confident)
#   3. ' use' (4.4% confident)
#   4. ' handle' (2.4% confident)
#   5. ' prepare' (2.2% confident)
# ✓ Chosen: ' get'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get'
#
# --- Step 17 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get'
# Top 20 next word predictions (showing first 5):
#   1. ' there' (8.8% confident)
#   2. ' to' (6.6% confident)
#   3. ' the' (4.5% confident)
#   4. ' in' (2.7% confident)
#   5. ' a' (2.4% confident)
# ✓ Chosen: ' on'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on'
#
# --- Step 18 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on'
# Top 20 next word predictions (showing first 5):
#   1. ' the' (30.5% confident)
#   2. ' with' (7.3% confident)
#   3. ' a' (3.9% confident)
#   4. ' board' (3.7% confident)
#   5. ' our' (3.1% confident)
# ✓ Chosen: ' board'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board'
#
# --- Step 19 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board'
# Top 20 next word predictions (showing first 5):
#   1. '.' (20.6% confident)
#   2. ' the' (5.8% confident)
#   3. ' with' (5.3% confident)
#   4. ',' (4.3% confident)
#   5. ' and' (3.6% confident)
# ✓ Chosen: '!'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board!'
#
# --- Step 20 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board!'
# Top 20 next word predictions (showing first 5):
#   1. '
# ' (24.4% confident)
#   2. '<|endoftext|>' (5.3% confident)
#   3. ' We' (2.1% confident)
#   4. ' I' (1.7% confident)
#   5. ' The' (1.7% confident)
# ✓ Chosen: ' If'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If'
#
# --- Step 21 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If'
# Top 20 next word predictions (showing first 5):
#   1. ' you' (50.3% confident)
#   2. ' we' (7.4% confident)
#   3. ' there' (2.8% confident)
#   4. ' the' (2.6% confident)
#   5. ' your' (2.3% confident)
# ✓ Chosen: ' there'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there'
#
# --- Step 22 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there'
# Top 20 next word predictions (showing first 5):
#   1. ' is' (36.0% confident)
#   2. ' are' (19.9% confident)
#   3. ''s' (17.6% confident)
#   4. '�' (6.1% confident)
#   5. ' was' (4.3% confident)
# ✓ Chosen: ' is'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is'
#
# --- Step 23 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is'
# Top 20 next word predictions (showing first 5):
#   1. ' any' (19.8% confident)
#   2. ' a' (17.1% confident)
#   3. ' anything' (8.8% confident)
#   4. ' one' (6.7% confident)
#   5. ' an' (4.3% confident)
# ✓ Chosen: ' any'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any'
#
# --- Step 24 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any'
# Top 20 next word predictions (showing first 5):
#   1. ' other' (2.6% confident)
#   2. ' information' (2.0% confident)
#   3. ' questions' (1.9% confident)
#   4. ' way' (1.3% confident)
#   5. ' question' (1.2% confident)
# ✓ Chosen: ' problem'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem'
#
# --- Step 25 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem'
# Top 20 next word predictions (showing first 5):
#   1. ',' (21.3% confident)
#   2. ' with' (16.3% confident)
#   3. ' or' (8.3% confident)
#   4. ' you' (4.8% confident)
#   5. ' please' (4.8% confident)
# ✓ Chosen: ' we'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we'
#
# --- Step 26 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we'
# Top 20 next word predictions (showing first 5):
#   1. ' can' (32.5% confident)
#   2. ' have' (6.6% confident)
#   3. ' would' (6.5% confident)
#   4. ' will' (5.5% confident)
#   5. ' could' (5.0% confident)
# ✓ Chosen: ' need'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we need'
#
# --- Step 27 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we need'
# Top 20 next word predictions (showing first 5):
#   1. ' to' (50.7% confident)
#   2. ' help' (22.0% confident)
#   3. ' a' (1.6% confident)
#   4. ' you' (1.3% confident)
#   5. ' an' (0.9% confident)
# ✓ Chosen: ' to'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we need to'
#
# --- Step 28 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we need to'
# Top 20 next word predictions (showing first 5):
#   1. ' contact' (5.2% confident)
#   2. ' help' (4.4% confident)
#   3. ' make' (4.2% confident)
#   4. ' get' (3.8% confident)
#   5. ' fix' (3.7% confident)
# ✓ Chosen: ' do'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we need to do'
#
# --- Step 29 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we need to do'
# Top 20 next word predictions (showing first 5):
#   1. ' something' (11.7% confident)
#   2. ' a' (10.7% confident)
#   3. ',' (3.1% confident)
#   4. ' some' (2.9% confident)
#   5. ' an' (2.8% confident)
# ✓ Chosen: ' this'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we need to do this'
#
# --- Step 30 ---
# Current: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we need to do this'
# Top 20 next word predictions (showing first 5):
#   1. ',' (6.6% confident)
#   2. ' quick' (2.9% confident)
#   3. ' in' (2.5% confident)
#   4. ' on' (2.3% confident)
#   5. ' and' (2.2% confident)
# ✓ Chosen: ' quick'
# New text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we need to do this quick'
#
#
# Final generated text: 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we need to do this quick'

# %%
print(repr(current_text))
# Out:
# 'The weather today is iced up and a couple of other factors could help us find out how to get on board! If there is any problem we need to do this quick'
